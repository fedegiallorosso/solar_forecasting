# %%
import datetime
import numpy as np
import pandas as pd
pd.set_option ('display.max_columns', None)

# %%
index= ["5:45","6:00","6:15","6:30","6:45","7:00","7:15","7:30","7:45", "8:00", "8:15","8:30", "8:45", "9:00", "9:15", "9:30", "9:45", "10:00", "10:15", "10:30", "10:45", "11:00","11:15", "11:30", "11:45" , "12:00", "12:15", "12:30", "12:45", "13:00", "13:15", "13:30", "13:45", "14:00", "14:15", "14:30", "14:45", "15:00", "15:15", "15:30", "15:45", "16:00", "16:15", "16:30", "16:45", "17:00" , "17:15", "17:30", "17:45", "18:00", "18:15"]
a = ["n/a","n/a","n/a","n/a","n/a","n/a", "n/a","n/a","n/a", "n/a","n/a","a", "a","a","9:15", "tbp", "tbp", "tbp","tbp", "a", "a", "a", "11:15", "tbp", "tbp", "tbp","tbp", "a", "a", "a","13:15","tbp", "tbp", "tbp","tbp", "a", "a", "a", "15:15", "tbp", "tbp", "tbp", "tbp", "n/a","n/a", "n/a", "n/a", "n/a", "n/a","n/a","n/a"]
b = ["n/a","n/a","n/a","n/a", "n/a","n/a", "n/a","n/a","n/a", "n/a","a","a","a", "9:00", "tbp", "tbp", "tbp","tbp", "a", "a", "a","11:00", "tbp", "tbp", "tbp","tbp", "a", "a", "a","13:00", "tbp", "tbp", "tbp","tbp", "a", "a", "a","15:00", "tbp", "tbp", "tbp", "tbp", "n/a", "n/a","n/a", "n/a", "n/a", "n/a", "n/a","n/a","n/a"]
c = ["n/a","n/a","n/a","n/a","n/a","n/a", "n/a","n/a","n/a", "a","a","a", "8:45", "tbp", "tbp", "tbp","tbp", "a", "a", "a","10:45", "tbp", "tbp", "tbp","tbp", "a", "a", "a","12:45","tbp", "tbp", "tbp","tbp", "a", "a", "a", "14:45", "tbp", "tbp", "tbp", "tbp", "n/a", "n/a", "n/a","n/a", "n/a", "n/a", "n/a", "n/a","n/a","n/a"]
d = ["n/a","n/a","n/a","n/a", "n/a","n/a", "n/a","n/a","a", "a","a","8:30", "tbp", "tbp", "tbp","tbp", "a", "a", "a","10:30", "tbp", "tbp", "tbp","tbp", "a", "a", "a","12:30","tbp", "tbp", "tbp","tbp", "a", "a", "a", "14:30", "tbp", "tbp", "tbp","tbp", "a", "a", "a","16:30", "tbp", "tbp", "tbp", "tbp", "n/a","n/a","n/a"]
e = ["n/a","n/a", "n/a","n/a","n/a","n/a", "n/a","a", "a","a","8:15", "tbp", "tbp", "tbp","tbp", "a", "a", "a","10:15", "tbp", "tbp", "tbp","tbp", "a", "a", "a","12:15","tbp", "tbp", "tbp","tbp", "a", "a", "a", "14:15", "tbp", "tbp", "tbp","tbp", "a", "a", "a","16:15", "tbp", "tbp", "tbp", "tbp", "n/a", "n/a","n/a","n/a"]
f = ["n/a","n/a", "n/a","n/a","n/a","n/a","a", "a","a","8:00", "tbp", "tbp", "tbp","tbp", "a", "a", "a","10:00", "tbp", "tbp", "tbp","tbp", "a", "a", "a","12:00","tbp", "tbp", "tbp","tbp", "a", "a", "a", "14:00", "tbp", "tbp", "tbp","tbp", "a", "a", "a","16:00", "tbp", "tbp", "tbp", "tbp", "n/a","n/a", "n/a","n/a","n/a"]
g = ["n/a","n/a","n/a", "n/a","n/a","a", "a","a","7:45", "tbp", "tbp", "tbp","tbp", "a", "a", "a","9:45", "tbp", "tbp", "tbp","tbp", "a", "a", "a","11:45","tbp", "tbp", "tbp","tbp", "a", "a", "a", "13:45", "tbp", "tbp", "tbp","tbp", "a", "a", "a","15:45", "tbp", "tbp", "tbp", "tbp", "n/a","n/a","n/a", "n/a","n/a","n/a"]
h = ["n/a","n/a","n/a","n/a", "a", "a","a","7:30", "tbp", "tbp", "tbp","tbp", "a", "a", "a","9:30", "tbp", "tbp", "tbp","tbp", "a", "a", "a","11:30","tbp", "tbp", "tbp","tbp", "a", "a", "a", "13:30", "tbp", "tbp", "tbp","tbp", "a", "a", "a","15:30", "tbp", "tbp", "tbp", "tbp", "n/a","n/a","n/a","n/a", "n/a","n/a","n/a"]
i = ["n/a","n/a","n/a", "a","a","a","7:15", "tbp", "tbp", "tbp","tbp", "a", "a", "a","9:15", "tbp", "tbp", "tbp","tbp", "a", "a", "a","11:15","tbp", "tbp", "tbp","tbp", "a", "a", "a", "13:15", "tbp", "tbp", "tbp","tbp", "a", "a", "a","15:15", "tbp", "tbp", "tbp", "tbp", "n/a","n/a","n/a","17:15", "tbp", "tbp", "tbp", "tbp"]
l = ["n/a", "n/a","a","a","a","7:00", "tbp", "tbp", "tbp","tbp", "a", "a", "a","9:00", "tbp", "tbp", "tbp","tbp", "a", "a", "a","11:00","tbp", "tbp", "tbp","tbp", "a", "a", "a", "13:00", "tbp", "tbp", "tbp","tbp", "a", "a", "a","15:00", "tbp", "tbp", "tbp", "tbp", "n/a","n/a","n/a","17:00", "tbp", "tbp", "tbp", "tbp", "n/a"]
m = ["n/a","a", "a","a","6:45", "tbp", "tbp", "tbp","tbp", "a", "a", "a","8:45", "tbp", "tbp", "tbp","tbp", "a", "a", "a","10:45","tbp", "tbp", "tbp","tbp", "a", "a", "a", "12:45", "tbp", "tbp", "tbp","tbp", "a", "a", "a","14:45", "tbp", "tbp", "tbp", "tbp", "n/a","n/a","n/a","16:45", "tbp", "tbp", "tbp", "tbp", "n/a", "n/a"]
n = ["a", "a","a","6:30", "tbp", "tbp", "tbp","tbp", "a", "a", "a","8:30", "tbp", "tbp", "tbp","tbp", "a", "a", "a","10:30","tbp", "tbp", "tbp","tbp", "a", "a", "a", "12:30", "tbp", "tbp", "tbp","tbp", "a", "a", "a","14:30", "tbp", "tbp", "tbp", "tbp", "n/a","n/a","n/a","16:30", "tbp", "tbp", "tbp", "tbp", "n/a", "n/a","n/a" ]
o = ["n/a","n/a", "n/a","n/a","n/a","n/a", "n/a","a", "a","a","8:15", "tbp", "tbp", "tbp","tbp", "a", "a", "a","10:15", "tbp", "tbp", "tbp","tbp", "a", "a", "a","12:15","tbp", "tbp", "tbp","tbp", "a", "a", "a", "14:15", "tbp", "tbp", "tbp","tbp", "a", "a", "a","n/a", "n/a", "n/a", "n/a", "n/a", "n/a", "n/a","n/a","n/a"]
p = ["n/a","n/a","n/a","n/a", "n/a","n/a", "n/a","n/a","a", "a","a","8:30", "tbp", "tbp", "tbp","tbp", "a", "a", "a","10:30", "tbp", "tbp", "tbp","tbp", "a", "a", "a","12:30","tbp", "tbp", "tbp","tbp", "a", "a", "a", "14:30", "tbp", "tbp", "tbp","tbp", "a", "a", "a","n/a", "n/a", "n/a", "n/a", "n/a", "n/a","n/a","n/a"]
df=pd.DataFrame ({"01.01 - 21.01":a, 
                  "22.01 - 08.02":b, 
                  "09.02 - 20.02":c, 
                  "21.02 - 02.03":d, 
                  "03.03 - 12.03":e,
                  "13.03 - 22.03":f,
                  "23.03 - 02.04":g,
                  "03.04 - 12.04":h, 
                  "13.04 - 24.04":i,
                  "25.04 - 09.05":l, 
                  "10.05 - 06.06":m,
                  "07.06 - 17.06":n,
                  "18.06 - 20.07":m,
                  "21.07 - 10.08":l,
                  "10.08 - 28.08":i, 
                  "29.08 - 16.09":h,
                  "17.09 - 4.10":g,
                  "5.10 - 20.10":f, 
                  "21.10 - 3.11":o,
                  "4.11 - 16.11":p, 
                  "17.11 - 30.11":c,
                  "01.12 - 18.12":b, 
                  "19.12 - 31.12":a},
                 index=index)
df
# Out:
#       01.01 - 21.01 22.01 - 08.02 09.02 - 20.02 21.02 - 02.03 03.03 - 12.03  \
# 5:45            n/a           n/a           n/a           n/a           n/a
# 6:00            n/a           n/a           n/a           n/a           n/a
# 6:15            n/a           n/a           n/a           n/a           n/a
# 6:30            n/a           n/a           n/a           n/a           n/a
# 6:45            n/a           n/a           n/a           n/a           n/a
# 7:00            n/a           n/a           n/a           n/a           n/a
# 7:15            n/a           n/a           n/a           n/a           n/a
# 7:30            n/a           n/a           n/a           n/a             a
# 7:45            n/a           n/a           n/a             a             a
# 8:00            n/a           n/a             a             a             a
# 8:15            n/a             a             a             a          8:15
# 8:30              a             a             a          8:30           tbp
# 8:45              a             a          8:45           tbp           tbp
# 9:00              a          9:00           tbp           tbp           tbp
# 9:15           9:15           tbp           tbp           tbp           tbp
# 9:30            tbp           tbp           tbp           tbp             a
# 9:45            tbp           tbp           tbp             a             a
# 10:00           tbp           tbp             a             a             a
# 10:15           tbp             a             a             a         10:15
# 10:30             a             a             a         10:30           tbp
# 10:45             a             a         10:45           tbp           tbp
# 11:00             a         11:00           tbp           tbp           tbp
# 11:15         11:15           tbp           tbp           tbp           tbp
# 11:30           tbp           tbp           tbp           tbp             a
# 11:45           tbp           tbp           tbp             a             a
# 12:00           tbp           tbp             a             a             a
# 12:15           tbp             a             a             a         12:15
# 12:30             a             a             a         12:30           tbp
# 12:45             a             a         12:45           tbp           tbp
# 13:00             a         13:00           tbp           tbp           tbp
# 13:15         13:15           tbp           tbp           tbp           tbp
# 13:30           tbp           tbp           tbp           tbp             a
# 13:45           tbp           tbp           tbp             a             a
# 14:00           tbp           tbp             a             a             a
# 14:15           tbp             a             a             a         14:15
# 14:30             a             a             a         14:30           tbp
# 14:45             a             a         14:45           tbp           tbp
# 15:00             a         15:00           tbp           tbp           tbp
# 15:15         15:15           tbp           tbp           tbp           tbp
# 15:30           tbp           tbp           tbp           tbp             a
# 15:45           tbp           tbp           tbp             a             a
# 16:00           tbp           tbp           n/a             a             a
# 16:15           tbp           n/a           n/a             a         16:15
# 16:30           n/a           n/a           n/a         16:30           tbp
# 16:45           n/a           n/a           n/a           tbp           tbp
# 17:00           n/a           n/a           n/a           tbp           tbp
# 17:15           n/a           n/a           n/a           tbp           tbp
# 17:30           n/a           n/a           n/a           tbp           n/a
# 17:45           n/a           n/a           n/a           n/a           n/a
# 18:00           n/a           n/a           n/a           n/a           n/a
# 18:15           n/a           n/a           n/a           n/a           n/a
#
#       13.03 - 22.03 23.03 - 02.04 03.04 - 12.04 13.04 - 24.04 25.04 - 09.05  \
# 5:45            n/a           n/a           n/a           n/a           n/a
# 6:00            n/a           n/a           n/a           n/a           n/a
# 6:15            n/a           n/a           n/a           n/a             a
# 6:30            n/a           n/a           n/a             a             a
# 6:45            n/a           n/a             a             a             a
# 7:00            n/a             a             a             a          7:00
# 7:15              a             a             a          7:15           tbp
# 7:30              a             a          7:30           tbp           tbp
# 7:45              a          7:45           tbp           tbp           tbp
# 8:00           8:00           tbp           tbp           tbp           tbp
# 8:15            tbp           tbp           tbp           tbp             a
# 8:30            tbp           tbp           tbp             a             a
# 8:45            tbp           tbp             a             a             a
# 9:00            tbp             a             a             a          9:00
# 9:15              a             a             a          9:15           tbp
# 9:30              a             a          9:30           tbp           tbp
# 9:45              a          9:45           tbp           tbp           tbp
# 10:00         10:00           tbp           tbp           tbp           tbp
# 10:15           tbp           tbp           tbp           tbp             a
# 10:30           tbp           tbp           tbp             a             a
# 10:45           tbp           tbp             a             a             a
# 11:00           tbp             a             a             a         11:00
# 11:15             a             a             a         11:15           tbp
# 11:30             a             a         11:30           tbp           tbp
# 11:45             a         11:45           tbp           tbp           tbp
# 12:00         12:00           tbp           tbp           tbp           tbp
# 12:15           tbp           tbp           tbp           tbp             a
# 12:30           tbp           tbp           tbp             a             a
# 12:45           tbp           tbp             a             a             a
# 13:00           tbp             a             a             a         13:00
# 13:15             a             a             a         13:15           tbp
# 13:30             a             a         13:30           tbp           tbp
# 13:45             a         13:45           tbp           tbp           tbp
# 14:00         14:00           tbp           tbp           tbp           tbp
# 14:15           tbp           tbp           tbp           tbp             a
# 14:30           tbp           tbp           tbp             a             a
# 14:45           tbp           tbp             a             a             a
# 15:00           tbp             a             a             a         15:00
# 15:15             a             a             a         15:15           tbp
# 15:30             a             a         15:30           tbp           tbp
# 15:45             a         15:45           tbp           tbp           tbp
# 16:00         16:00           tbp           tbp           tbp           tbp
# 16:15           tbp           tbp           tbp           tbp           n/a
# 16:30           tbp           tbp           tbp           n/a           n/a
# 16:45           tbp           tbp           n/a           n/a           n/a
# 17:00           tbp           n/a           n/a           n/a         17:00
# 17:15           n/a           n/a           n/a         17:15           tbp
# 17:30           n/a           n/a           n/a           tbp           tbp
# 17:45           n/a           n/a           n/a           tbp           tbp
# 18:00           n/a           n/a           n/a           tbp           tbp
# 18:15           n/a           n/a           n/a           tbp           n/a
#
#       10.05 - 06.06 07.06 - 17.06 18.06 - 20.07 21.07 - 10.08 10.08 - 28.08  \
# 5:45            n/a             a           n/a           n/a           n/a
# 6:00              a             a             a           n/a           n/a
# 6:15              a             a             a             a           n/a
# 6:30              a          6:30             a             a             a
# 6:45           6:45           tbp          6:45             a             a
# 7:00            tbp           tbp           tbp          7:00             a
# 7:15            tbp           tbp           tbp           tbp          7:15
# 7:30            tbp           tbp           tbp           tbp           tbp
# 7:45            tbp             a           tbp           tbp           tbp
# 8:00              a             a             a           tbp           tbp
# 8:15              a             a             a             a           tbp
# 8:30              a          8:30             a             a             a
# 8:45           8:45           tbp          8:45             a             a
# 9:00            tbp           tbp           tbp          9:00             a
# 9:15            tbp           tbp           tbp           tbp          9:15
# 9:30            tbp           tbp           tbp           tbp           tbp
# 9:45            tbp             a           tbp           tbp           tbp
# 10:00             a             a             a           tbp           tbp
# 10:15             a             a             a             a           tbp
# 10:30             a         10:30             a             a             a
# 10:45         10:45           tbp         10:45             a             a
# 11:00           tbp           tbp           tbp         11:00             a
# 11:15           tbp           tbp           tbp           tbp         11:15
# 11:30           tbp           tbp           tbp           tbp           tbp
# 11:45           tbp             a           tbp           tbp           tbp
# 12:00             a             a             a           tbp           tbp
# 12:15             a             a             a             a           tbp
# 12:30             a         12:30             a             a             a
# 12:45         12:45           tbp         12:45             a             a
# 13:00           tbp           tbp           tbp         13:00             a
# 13:15           tbp           tbp           tbp           tbp         13:15
# 13:30           tbp           tbp           tbp           tbp           tbp
# 13:45           tbp             a           tbp           tbp           tbp
# 14:00             a             a             a           tbp           tbp
# 14:15             a             a             a             a           tbp
# 14:30             a         14:30             a             a             a
# 14:45         14:45           tbp         14:45             a             a
# 15:00           tbp           tbp           tbp         15:00             a
# 15:15           tbp           tbp           tbp           tbp         15:15
# 15:30           tbp           tbp           tbp           tbp           tbp
# 15:45           tbp           n/a           tbp           tbp           tbp
# 16:00           n/a           n/a           n/a           tbp           tbp
# 16:15           n/a           n/a           n/a           n/a           tbp
# 16:30           n/a         16:30           n/a           n/a           n/a
# 16:45         16:45           tbp         16:45           n/a           n/a
# 17:00           tbp           tbp           tbp         17:00           n/a
# 17:15           tbp           tbp           tbp           tbp         17:15
# 17:30           tbp           tbp           tbp           tbp           tbp
# 17:45           tbp           n/a           tbp           tbp           tbp
# 18:00           n/a           n/a           n/a           tbp           tbp
# 18:15           n/a           n/a           n/a           n/a           tbp
#
#       29.08 - 16.09 17.09 - 4.10 5.10 - 20.10 21.10 - 3.11 4.11 - 16.11  \
# 5:45            n/a          n/a          n/a          n/a          n/a
# 6:00            n/a          n/a          n/a          n/a          n/a
# 6:15            n/a          n/a          n/a          n/a          n/a
# 6:30            n/a          n/a          n/a          n/a          n/a
# 6:45              a          n/a          n/a          n/a          n/a
# 7:00              a            a          n/a          n/a          n/a
# 7:15              a            a            a          n/a          n/a
# 7:30           7:30            a            a            a          n/a
# 7:45            tbp         7:45            a            a            a
# 8:00            tbp          tbp         8:00            a            a
# 8:15            tbp          tbp          tbp         8:15            a
# 8:30            tbp          tbp          tbp          tbp         8:30
# 8:45              a          tbp          tbp          tbp          tbp
# 9:00              a            a          tbp          tbp          tbp
# 9:15              a            a            a          tbp          tbp
# 9:30           9:30            a            a            a          tbp
# 9:45            tbp         9:45            a            a            a
# 10:00           tbp          tbp        10:00            a            a
# 10:15           tbp          tbp          tbp        10:15            a
# 10:30           tbp          tbp          tbp          tbp        10:30
# 10:45             a          tbp          tbp          tbp          tbp
# 11:00             a            a          tbp          tbp          tbp
# 11:15             a            a            a          tbp          tbp
# 11:30         11:30            a            a            a          tbp
# 11:45           tbp        11:45            a            a            a
# 12:00           tbp          tbp        12:00            a            a
# 12:15           tbp          tbp          tbp        12:15            a
# 12:30           tbp          tbp          tbp          tbp        12:30
# 12:45             a          tbp          tbp          tbp          tbp
# 13:00             a            a          tbp          tbp          tbp
# 13:15             a            a            a          tbp          tbp
# 13:30         13:30            a            a            a          tbp
# 13:45           tbp        13:45            a            a            a
# 14:00           tbp          tbp        14:00            a            a
# 14:15           tbp          tbp          tbp        14:15            a
# 14:30           tbp          tbp          tbp          tbp        14:30
# 14:45             a          tbp          tbp          tbp          tbp
# 15:00             a            a          tbp          tbp          tbp
# 15:15             a            a            a          tbp          tbp
# 15:30         15:30            a            a            a          tbp
# 15:45           tbp        15:45            a            a            a
# 16:00           tbp          tbp        16:00            a            a
# 16:15           tbp          tbp          tbp          n/a            a
# 16:30           tbp          tbp          tbp          n/a          n/a
# 16:45           n/a          tbp          tbp          n/a          n/a
# 17:00           n/a          n/a          tbp          n/a          n/a
# 17:15           n/a          n/a          n/a          n/a          n/a
# 17:30           n/a          n/a          n/a          n/a          n/a
# 17:45           n/a          n/a          n/a          n/a          n/a
# 18:00           n/a          n/a          n/a          n/a          n/a
# 18:15           n/a          n/a          n/a          n/a          n/a
#
#       17.11 - 30.11 01.12 - 18.12 19.12 - 31.12
# 5:45            n/a           n/a           n/a
# 6:00            n/a           n/a           n/a
# 6:15            n/a           n/a           n/a
# 6:30            n/a           n/a           n/a
# 6:45            n/a           n/a           n/a
# 7:00            n/a           n/a           n/a
# 7:15            n/a           n/a           n/a
# 7:30            n/a           n/a           n/a
# 7:45            n/a           n/a           n/a
# 8:00              a           n/a           n/a
# 8:15              a             a           n/a
# 8:30              a             a             a
# 8:45           8:45             a             a
# 9:00            tbp          9:00             a
# 9:15            tbp           tbp          9:15
# 9:30            tbp           tbp           tbp
# 9:45            tbp           tbp           tbp
# 10:00             a           tbp           tbp
# 10:15             a             a           tbp
# 10:30             a             a             a
# 10:45         10:45             a             a
# 11:00           tbp         11:00             a
# 11:15           tbp           tbp         11:15
# 11:30           tbp           tbp           tbp
# 11:45           tbp           tbp           tbp
# 12:00             a           tbp           tbp
# 12:15             a             a           tbp
# 12:30             a             a             a
# 12:45         12:45             a             a
# 13:00           tbp         13:00             a
# 13:15           tbp           tbp         13:15
# 13:30           tbp           tbp           tbp
# 13:45           tbp           tbp           tbp
# 14:00             a           tbp           tbp
# 14:15             a             a           tbp
# 14:30             a             a             a
# 14:45         14:45             a             a
# 15:00           tbp         15:00             a
# 15:15           tbp           tbp         15:15
# 15:30           tbp           tbp           tbp
# 15:45           tbp           tbp           tbp
# 16:00           n/a           tbp           tbp
# 16:15           n/a           n/a           tbp
# 16:30           n/a           n/a           n/a
# 16:45           n/a           n/a           n/a
# 17:00           n/a           n/a           n/a
# 17:15           n/a           n/a           n/a
# 17:30           n/a           n/a           n/a
# 17:45           n/a           n/a           n/a
# 18:00           n/a           n/a           n/a
# 18:15           n/a           n/a           n/a

# %% [markdown]
# Given the date returns the relative number of observations

# %%
def numb_obser (actual_day):
    dx = datetime.datetime.strptime(actual_day, "%d-%m-%Y")
    dx= dx.date()

    d1 = datetime.date(2012,1,1)
    d2 = datetime.date(2012,2,20)
    d3 = datetime.date(2012,4,12)
    d4 = datetime.date(2012,8,28)
    d5 = datetime.date(2012,10,20)
    d6 = datetime.date(2012,12,31)
    
    obs=0
    if dx>=d1 and dx<=d2:
        obs=4    
    elif dx>d2 and dx<=d3:
        obs=5
    elif dx>d3 and dx<=d4:
        obs=6
    elif dx>d4 and dx<=d5:
        obs=5
    elif dx>d5 and dx<=d6:
        obs=4

    if obs!=0:
        return (f"the number of observation per day is {obs}")
    else:
        return ("date out of the range")

# %%
numb_obser(input("Give me the actual day (dd-mm-yyyy): "))
# Out:
# 'the number of observation per day is 6'

# %%
data = np.load('../raw_data/baseline.npz', allow_pickle=True)

# %%
def index (actual_day):
    
    riv= data['datetime']
    date_format=[]
    for i in range(riv.shape[0]):
        date_format.append(riv[i].date()) 
    dx = datetime.datetime.strptime(actual_day, "%d-%m-%Y")
    dx = dx.date()
    index = []
    for i in range(riv.shape[0]):
        if dx == date_format[i]:
            index.append(i)
    if not index:
        return ("date out of the range")
    else:
        return index

# %%
index (input ("Give me the actual day (dd-mm-yyyy): "))
# Out:
# [1477, 1478, 1479, 1480, 1481]
